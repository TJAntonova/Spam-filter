# %% [markdown]
# # Spam filter

# %%
import pandas as pd
import re
import en_core_web_sm

# %% [markdown]
# ### Step 1. Preprocessing

# %%
df = pd.read_csv('spam.csv', encoding='iso-8859-1')
df_new = df.iloc[:, [0, 1]]
df_new = df_new.rename({'v1':'Target', 'v2':'SMS'}, axis=1)

# iteration over the dataframe and conversion the text to lowercase;
rows = []
for index, row in df_new.iterrows():
    row = row['SMS'].lower()
    rows.append(row)

# lemmatization, punctuation removal
en_sm_model = en_core_web_sm.load()

a = []
for i in rows:
    doc = en_sm_model(i)
    tokens = []
    for r in doc:
        r = "{0} – {1}".format(r.lemma_, r.pos_)
        tokens.append(r)

# removal of pos tags, initial form, replacement of numbers, removal of words consisting of one letter
    tokenss=[]
    for i in tokens:
        i = re.sub('...[A-Z]+','',i).strip()
        i = re.sub('.*\d+.*','aanumbers',i).strip()
        i = re.sub('[!"#$%&\'()*+,-./:;<=>?@^_`{|}~]+', '', i).strip()
        i = re.sub('\\\\', '', i).strip()
        if len(i) > 1:
            tokenss.append(i)

    a.append(tokenss)

# removal of stop words
from spacy.lang.en.stop_words import STOP_WORDS

sw = []
c = []
for i in a:
    c = []
    for w in i:
        if w not in STOP_WORDS:

            if w == 'aanumber':
                c.append('aanumbers')
            else:
                c.append(w)
    sw.append(c)

swn = []
for i in sw:
    i = ' '.join(i)
    swn.append(i)

# dataframe upgrade
df_new.drop(columns = ['SMS'],axis = 1)
df_new['SMS'] = swn

pd.options.display.max_columns = df_new.shape[1]
pd.options.display.max_rows = df_new.shape[0]

print(df_new.head(200))
# Out:
#     Target                                                SMS
# 0      ham  jurong point crazy available bugis great world...
# 1      ham                                ok lar joke wif oni
# 2     spam  free entry aanumbers wkly comp win fa cup fina...
# 3      ham                                      dun early hor
# 4      ham                                 nah think usf live
# 5     spam  freemsg hey darle aanumbers week word like fun...
# 6      ham          brother like speak treat like aids patent
# 7      ham  request melle melle oru minnaminunginte nurung...
# 8     spam  winner value network customer select receivea ...
# 9     spam  mobile aanumbers month entitle update late col...
# 10     ham  home soon want talk stuff anymore tonight ve c...
# 11    spam  chance win cash aanumbers aanumbers pound txt ...
# 12    spam  urgent win aanumbers week free membership aanu...
# 13     ham  ve search right word thank breather promise he...
# 14     ham                                        date sunday
# 15    spam  xxxmobilemovieclub use credit click wap link t...
# 16     ham                                        oh im watch
# 17     ham        eh remember aanumbers spell yes naughty wet
# 18     ham             fine thatåõs way feel thatåõs way gota
# 19    spam  england macedonia miss goal team news txt ur n...
# 20     ham                                    seriously spell
# 21     ham               iû÷m try aanumbers month ha ha joke
# 22     ham                             pay lar da stock comin
# 23     ham  aft finish lunch str lor ard aanumbers smth lo...
# 24     ham                   ffffffffff alright way meet soon
# 25     ham  force eat slice hungry tho suck mark worried k...
# 26     ham                                     lol convincing
# 27     ham  catch bus fry egg tea eat mom leave dinner fee...
# 28     ham                         amp pack car let know room
# 29     ham           ahhh work vaguely remember feel like lol
# 30     ham                wait clear sure sarcastic want live
# 31     ham  yeah aanumbers apologetic fall actin like spoi...
# 32     ham                                               tell
# 33     ham                   fear faint housework quick cuppa
# 34    spam  thank subscription ringtone uk mobile charge a...
# 35     ham  yup ok home look timing msg xuhui learn aanumb...
# 36     ham                              oop let know roommate
# 37     ham                                         letter car
# 38     ham                                         lor decide
# 39     ham        hello saturday texte decide tomo try invite
# 40     ham      pls ahead watt want sure great weekend abiola
# 41     ham  forget tell want need crave love sweet arabian...
# 42    spam  aanumbers rodger burn msg try reply sms free n...
# 43     ham
# 44     ham                great hope like man endow ltgt inch
# 45     ham                                       message miss
# 46     ham                           hep immunisation nigeria
# 47     ham                                               fair
# 48     ham                 yeah hopefully tyler maybe ask bit
# 49     ham  know stubborn want hospital tell mark weak suc...
# 50     ham                                   think time class
# 51     ham  gram usually run like ltgt half eighth smart s...
# 52     ham  fyi ride early tomorrow morning crash place to...
# 53     ham  wow realize embarasse accomodation think like ...
# 54    spam  sms ac sptv new jersey devil detroit red wing ...
# 55     ham       know mallika sherawat yesterday find lturlgt
# 56    spam  congrat aanumbers year special cinema pass aan...
# 57     ham                                sorry later meeting
# 58     ham                                         tell reach
# 59     ham                        yes gauti sehwag odi series
# 60     ham           pick aanumbers burger way home pain kill
# 61     ham           ha ha ha good joke girl situation seeker
# 62     ham                                           check iq
# 63     ham                     sorry roommate forever ok come
# 64     ham  ok lar double check wif da hair dresser wun cu...
# 65    spam  value customer pleased advise follow recent re...
# 66     ham  today song dedicated day song dedicate send ur...
# 67    spam  urgent ur award complimentary trip eurodisinc ...
# 68    spam             hear new divorce barbie come ken stuff
# 69     ham                                    plane month end
# 70     ham                       wah lucky man save money hee
# 71     ham                                     finished class
# 72     ham                              hi babe home wanna xx
# 73     ham                              kwhere youhow perform
# 74     ham
# 75     ham                                   wait machan free
# 76     ham               cool gentleman treat dignity respect
# 77     ham                                 like people shy pa
# 78     ham                                       operate ltgt
# 79     ham                                   look job ta earn
# 80     ham                                        sorry later
# 81     ham                                                 ah
# 82     ham                                  ok way home hi hi
# 83     ham                                          place man
# 84     ham                                           yup stop
# 85     ham                             later network urgnt sm
# 86     ham    real yo need aanumbers ticket jacket use multis
# 87     ham  yes start send request pain come bed double co...
# 88     ham                                       tonight babe
# 89     ham              ela kano il download come wen ur free
# 90     ham        yeah donû÷t stand close tho youû÷ll catch
# 91     ham  sorry pain ok meet night spend late afternoon ...
# 92     ham  smile pleasure smile pain smile trouble pour l...
# 93    spam  customer service representative aanumbers aanu...
# 94     ham  plan buy later check lido aanumbers afternoon ...
# 95    spam  free ringtone wait collect simply text passwor...
# 96     ham                         watch telugu movie wat abt
# 97     ham                               finish load loan pay
# 98     ham  hi wk ok hol yes bit run forgot hairdresser ap...
# 99     ham                                       text anymore
# 100    ham       okay ur price long legal wen pick ave ams xx
# 101    ham                look car buy aanumbers driving test
# 102    ham  request melle melle oru minnaminunginte nurung...
# 103    ham  wow right mean guess boston man change search ...
# 104    ham                  umma life vava umma love lot dear
# 105    ham  thank lot wish birthday thank birthday truly m...
# 106    ham                                     aight hit cash
# 107    ham  ip address test consider computer minecraft se...
# 108    ham      know grumpy old people mom like lie play joke
# 109    ham                                   worry guess busy
# 110    ham                               plural noun research
# 111    ham                                          dinnermsg
# 112    ham  ok wif cos like aanumbers try new thing scare ...
# 113   spam  gent try contact weekend draw win aanumbers pr...
# 114    ham  wa ur openin sentence formal fine juz tt eatin...
# 115    ham  enter cabin pa happy bday boss feel special as...
# 116   spam  winner specially select aanumbers receive aanu...
# 117    ham  goodo yes speak friday egg potato ratio tortil...
# 118    ham  hmm uncle inform pay school directly pls buy food
# 119   spam  private aanumbers account statement aanumbers ...
# 120   spam  urgent mobile award aanumbers bonus caller pri...
# 121    ham                 new address applespairsall malarky
# 122   spam  today voda number end aanumbers select receive...
# 123    ham                             sao mu today aanumbers
# 124    ham                 ìï predict wat time ìll finish buy
# 125    ham                                         good stuff
# 126    ham  know yetunde send money send text bother send ...
# 127    ham                                               room
# 128    ham    hey girl hope del bak long time sum time lucyxx
# 129    ham                                          khow cost
# 130    ham                                               home
# 131    ham                         dear tmorrowpls accomodate
# 132    ham                                    answer question
# 133   spam  sunshine quiz wkly win sony dvd player know co...
# 134   spam  want aanumbers lay tonight want real dogging l...
# 135    ham                            haf msn yijuehotmailcom
# 136    ham                                               meet
# 137    ham                          check room befor activity
# 138   spam  rcv msg chat svc free hardcore service text aa...
# 139    ham              lazy type forget lect pouch like nice
# 140    ham                                           text way
# 141    ham                                      sir wait mail
# 142    ham  swt think nver tired little thing aanumbers lo...
# 143    ham                                      know pls open
# 144    ham                                         yes ya dot
# 145    ham                                        staff class
# 146   spam  freemsg reply text randy sexy female live loca...
# 147    ham  ummmawill check inour life begin qatar pls pra...
# 148    ham                                     delete contact
# 149    ham                               sindu job birla soft
# 150    ham                                   wine flow nevere
# 151    ham  yup thk cine cos need aanumbers aanumbers plaz...
# 152    ham                                ok ur typical reply
# 153    ham  request melle melle oru minnaminunginte nurung...
# 154    ham  dirt floor window shirt open mouth come flow d...
# 155    ham                                   aaooooright work
# 156    ham                                        leave house
# 157    ham  hello love interview today happy good boy thin...
# 158   spam  customer service annoncement new year delivery...
# 159   spam  winner specially select aanumbers receive aanu...
# 160    ham                      safe need miss envy real life
# 161    ham                new car house parentsi new job hand
# 162    ham                       love excited day spend happy
# 163   spam  pls stop bootydelious aanumbers invite friend ...
# 164   spam  bangbabe ur order way receive service msg aanu...
# 165    ham                      place ur point culture module
# 166   spam  urgent try contact weekend draw win aanumbers ...
# 167    ham   hi frnd good way avoid missunderstde wit beloved
# 168    ham          great escape fancy bridge need lager tomo
# 169    ham               yes completely formclark utter waste
# 170    ham            sir need axis bank account bank address
# 171    ham  hmmm thk sure time hop ard ya aanumbers free a...
# 172    ham                                    time come later
# 173    ham  bloody hell believe forget surname mr ill clue...
# 174    ham                        finish bath good fine night
# 175    ham                           let know ve money carlos
# 176    ham                                               mall
# 177    ham  turn friend stay til ltgt feel free ahead smok...
# 178    ham                            text reply let know log
# 179    ham  hi speak maneesha like know satisfied experien...
# 180    ham  lift hope offer money need especially end mont...
# 181    ham                                          lol trust
# 182    ham                 ok gentleman treat dignity respect
# 183    ham                                          guy close
# 184    ham                                           greatbye
# 185    ham  hello handsome find job lazy work net mummy bo...
# 186    ham                                haha awesome minute
# 187   spam  customer service representative freephone aanu...
# 188    ham                                    xmas radio time
# 189    ham        ju reach home bathe sis use net tell finish
# 190   spam   unique find aanumbers august wwwareyouuniquecouk
# 191    ham  sorry ve join league people touch mean great d...
# 192    ham                         hi finally complete course
# 193    ham                       stop suggest stay able stool
# 194    ham  hope ve settle new school year wishin aanumber...
# 195    ham                         gud mrng dear hav nice day
# 196    ham                                       person story
# 197    ham  hamster dead hey tmr meet aanumbers pm orchard...
# 198    ham  hi kate evening hope tomorrow bit bloody babyj...
# 199    ham                                      find enc ltgt

# %% [markdown]
# ### Step 2. Naive Bayes classifier

# %%
# train-test split
df = df_new
df = df.sample(n=df.shape[0], random_state=43)
train_last_index = int(df.shape[0] * 0.8)
train_set = df.iloc[0:train_last_index]
test_set = df.iloc[train_last_index:]
train_set.reset_index(drop=True, inplace=True)


#train_set.to_csv('train_set.csv')
#print('train_set is writen')

# %%
vocab = set()
for row in train_set['SMS']:
    vocab.update(row.split())
vocab = list(vocab)
vocab = sorted(vocab)

# %%
def bayes(data1, data2=train_set['SMS'], vocab=vocab):
    sum_of_all_words = 0
    all_words = []
    for row in data1['SMS']:
        row = row.split()
        for el in row:
            all_words.append(el)
    for word in all_words:
        sum_of_all_words += 1

    sum_of_vocab = 0
    for v in vocab:
        sum_of_vocab += 1

    sum_of_word_lst = []
    for w in vocab:
        vec = []
        for el in all_words:
            if w == el:
                vec.append(1)
            else:
                vec.append(0)
        sum_of_word_lst.append(vec)
        
    sum_of_word = []
    for lst in sum_of_word_lst:
        sum = 0
        for el in lst:
            sum += el
        sum_of_word.append(sum)

    acp = []
    for i in range(len(sum_of_word)):
        probability = (sum_of_word[i] + 1) / (sum_of_all_words + sum_of_vocab)
        acp.append(format(probability, 'f'))

    return acp

# %%
spam = bayes(train_set.loc[train_set['Target'] == 'spam'])
ham = bayes(train_set.loc[train_set['Target'] == 'ham'])

d = {'Spam Probability': spam, 'Ham Probability': ham}
df_bayes = pd.DataFrame(d, index=vocab)
df_bayes['ind'] = df_bayes.index

pd.options.display.max_rows=204
print(df_bayes.head(5))
# Out:
#           Spam Probability  ...        ind
# aa                0.000066  ...         aa
# aah               0.000066  ...        aah
# aanumbers         0.156118  ...  aanumbers
# aathi             0.000066  ...      aathi
# abbey             0.000066  ...      abbey
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Step 3. Probabilities of spam

# %%
def prob_s_h(s_h, data=train_set):
    s = []
    for i in data['SMS']:
        s.append(i)
    s = len(s)
    lsts = []
    for i in s_h['SMS']:
        lsts.append(i)
    ss = len(lsts)
    p = ss / s
    return p


p_spam = prob_s_h(train_set.loc[train_set['Target'] == 'spam'])
p_ham = prob_s_h(train_set.loc[train_set['Target'] == 'ham'])

# %%
sents = []
for i in train_set['SMS']:
    i = str(i).split()
    sents.append(i)

sents_p = []
for s in sents:
    s_p = []
    for w in s:
        p = str(df_bayes.loc[df_bayes['ind'] == w, 'Spam Probability']).split()
        p = p[1]
        if p != 'Name:':
            s_p.append(float(p))
    sents_p.append(s_p)
    
probs = []
for s in sents_p:
    prob = 1
    for w in s:
        prob*=w
    probs.append(prob*p_spam)

sents_p_h = []
for s in sents:
    s_p = []
    for w in s:
        p = str(df_bayes.loc[df_bayes['ind'] == w, 'Ham Probability']).split()
        p = p[1]
        if p != 'Name:':
            s_p.append(float(p))
    sents_p_h.append(s_p)
    
probs_h = []
for s in sents_p_h:
    prob = 1
    for w in s:
        prob*=w
    probs_h.append(prob*p_ham)

data = []
for i in range(len(sents)):
    if probs[i] > probs_h[i]:
        data.append('spam')
    elif probs[i] < probs_h[i]:
        data.append('ham')
    else:
        data.append('unknown')

train_set.insert(loc=0, column='Predicted', value=data)
train_set.rename(columns={'Target': 'Actual'}, inplace=True)
train_set.drop(columns=['SMS'], axis=1, inplace=True)

print(train_set)
# Out:
#      Predicted Actual
# 0          ham    ham
# 1          ham    ham
# 2          ham    ham
# 3          ham    ham
# 4          ham    ham
# ...        ...    ...
# 4452       ham    ham
# 4453       ham    ham
# 4454       ham    ham
# 4455       ham    ham
# 4456       ham    ham
#
# [4457 rows x 2 columns]
# C:\Users\js\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\js\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ###  Step 4. Model performance

# %%
predict = []
act = []
for i in train_set['Predicted']:
    predict.append(i)
for i in train_set['Actual']:
    act.append(i)
tp = 0
tn = 0
fp = 0
fn = 0
for i in range(len(predict)):
    if predict[i] == 'ham':
        if predict[i] == act[i]:
            tp+=1
        else:
            fp+=1
    else:
        if predict[i] == act[i]:
            tn+=1
        else:
            fn+=1

accuracy = (tp+tn)/(tp+tn+fp+fn)
recall = tp/(tp+fn)
precision = tp / (tp+fp)
f1 = 2*precision*recall/(precision+recall)
d = {'Accuracy': accuracy, 'Recall': recall, 'Precision': precision, 'F1': f1}
print(d)
# Out:
# {'Accuracy': 0.9896791563832175, 'Recall': 0.9922239502332815, 'Precision': 0.9958376690946931, 'F1': 0.9940275253180992}
